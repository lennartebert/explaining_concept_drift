# %% [markdown]
# # Preprocess Data

# %%
import os
import opyenxes
from opyenxes.data_in import XMxmlParser
from opyenxes.data_out import XesXmlSerializer

# %% [markdown]
# ## Maaradji et al. 2013 Dataset
# - The dataset needs to be converted to XES for importing into pm4py
# - For each event log, a true list of all changepoints should be generated (every 10% of traces).
# - Simplify the folder structure in only a list of XES event logs plus their according changepoints.
# - Add artificial feature data that can explain the concept drift.

# %%
# set the from and to path
from_path = 'data/synthetic/maardji et al 2013_mxml/'
to_path = 'data/synthetic/maardji et al 2013_xes/'

# %%
# get all mxml event log files from the from_path
list_of_files = list()
for (dirpath, dirnames, filenames) in os.walk(from_path):
    list_of_files += [os.path.join(dirpath, file) for file in filenames]

list_of_mxml_log_paths = [file for file in list_of_files if file.lower().endswith('mxml')]

# %%
# convert each log to XES and save it in the to path
to_path_logs = os.path.join(to_path, 'logs')
    
# create to_path if not existing
if not os.path.exists(to_path):
    # Create a new directory because it does not exist 
    os.makedirs(to_path)

xes_log_file_paths = []
for mxml_log_path in list_of_mxml_log_paths:
    # read the mxml log into OpyenXes
    mxml_parser = XMxmlParser.XMxmlParser()
    parsed_logs = None
    with open(mxml_log_path) as mxml_log_file:
        parsed_logs = mxml_parser.parse(mxml_log_file)
    
    # Our mxml files always only contain one log. Therefore, access this log
    parsed_log = parsed_logs[0]
    
    # get the output path
    file_name = os.path.basename(mxml_log_path)
    print(file_name)
    # remove the suffix
    file_name = os.path.splitext(file_name)[0]
    # append .xes
    file_name = file_name + '.xes'
    
    to_file_path = os.path.join(to_path_logs, file_name)
    xes_log_file_paths.append(to_file_path)
    
    # write the XES log out
    with open(to_file_path, 'w') as to_file:
        # save log back to XES file
        XesXmlSerializer.XesXmlSerializer().serialize(parsed_log, to_file)
# Out:
# cb10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (23797.61181640625 msec.)
#
# cb2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (8428.402587890625 msec.)
#
# cb5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (13311.8203125 msec.)
#
# cb7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (20389.671875 msec.)
#
# cb7.5k-checkpoint.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (23568.2236328125 msec.)
#
# cd10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (29876.697998046875 msec.)
#
# cd2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (10071.223876953125 msec.)
#
# cd5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (15565.11328125 msec.)
#
# cd7.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (25268.608642578125 msec.)
#
# cf10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (24341.87451171875 msec.)
#
# cf2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (6217.3447265625 msec.)
#
# cf5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (13631.714599609375 msec.)
#
# cf7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (22575.902099609375 msec.)
#
# cm10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (26946.947998046875 msec.)
#
# cm2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (9145.30029296875 msec.)
#
# cm5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (14209.902587890625 msec.)
#
# cm7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (21690.00732421875 msec.)
#
# cp10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (32024.36181640625 msec.)
#
# cp2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (9608.914794921875 msec.)
#
# cp5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (16329.75439453125 msec.)
#
# cp7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (20975.328369140625 msec.)
#
# fr10k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (31669.691650390625 msec.)
#
# fr2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (9586.0439453125 msec.)
#
# fr5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (14277.543212890625 msec.)
#
# fr7.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (18897.6435546875 msec.)
#
# IOR10k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (26613.289306640625 msec.)
#
# IOR2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (10175.0419921875 msec.)
#
# IOR5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (14556.565673828125 msec.)
#
# IOR7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (25127.2216796875 msec.)
#
# IRO10k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (35059.25390625 msec.)
#
# IRO2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (9620.638916015625 msec.)
#
# IRO5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (13630.22900390625 msec.)
#
# IRO7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (23452.972412109375 msec.)
#
# lp10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (49640.373046875 msec.)
#
# lp2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (14529.34765625 msec.)
#
# lp5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (31258.31103515625 msec.)
#
# lp7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (48728.549560546875 msec.)
#
# OIR10k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (26796.30078125 msec.)
#
# OIR2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (7506.24365234375 msec.)
#
# OIR5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (17187.481689453125 msec.)
#
# OIR7.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (23978.24755859375 msec.)
#
# ORI10k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (28313.66943359375 msec.)
#
# ORI2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (6257.284912109375 msec.)
#
# ORI5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (16054.310546875 msec.)
#
# ORI7.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (23130.081787109375 msec.)
#
# pl10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (27763.292236328125 msec.)
#
# pl2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (8528.37109375 msec.)
#
# pl5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (14046.743408203125 msec.)
#
# pl7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (23586.477783203125 msec.)
#
# pm10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (29604.22119140625 msec.)
#
# pm2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (10808.02783203125 msec.)
#
# pm5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (15177.694091796875 msec.)
#
# pm7.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (21651.69189453125 msec.)
#
# re10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (59369.94921875 msec.)
#
# re2.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (13866.939453125 msec.)
#
# re5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (26724.65478515625 msec.)
#
# re7.5k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (42246.56884765625 msec.)
#
# RIO10k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (30341.014404296875 msec.)
#
# RIO2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (9708.70166015625 msec.)
#
# RIO5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (18908.0244140625 msec.)
#
# RIO7.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (25149.733642578125 msec.)
#
# ROI10k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (30390.724853515625 msec.)
#
# ROI2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (8223.540283203125 msec.)
#
# ROI5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (12803.314208984375 msec.)
#
# ROI7.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (28411.172607421875 msec.)
#
# rp10k.mxml
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (42762.435302734375 msec.)
#
# rp2.5k.MXML
# Importance: DEBUG
# Message: Start serializing log to XES.XML
#
# Importance: DEBUG
# Message: finished serializing log (11985.137451171875 msec.)

# %%
# create a data dictionary that has a list of changepoint locations for each event log
data_dictionary = {}
for log_file_path in xes_log_file_paths:
    log_info = {}
    log_info['file_path'] = log_file_path
    
    # get the cleaned file name
    file_name =  os.path.basename(log_file_path)
    # remove the suffix
    file_name = os.path.splitext(file_name)[0]
    log_info['file_name'] = file_name
    
    log_info['drift_type'] = 'sudden'
    log_info['dataset'] = 'maardji et al 2013'
    
    size = None
    if '2.5k' in file_name:
        size = 2500
    elif '7.5k' in file_name:
        size = 7500
    elif '10k' in file_name:
        size = 10000
    elif '5k' in file_name: # This statement has to come last so that there is no confusion with the other names that have a 5 in them.
        size = 5000
    log_info['size'] = size
    
    changepoints = [(int) (size * (i+1)/10) for i in range(9)]
    log_info['changepoints'] = changepoints
    
    # TODO Could implement the change pattern name here. For now, users can looks this up through the file_name and paper by Maardji et al. 2013
    data_dictionary[log_file_path] = log_info
